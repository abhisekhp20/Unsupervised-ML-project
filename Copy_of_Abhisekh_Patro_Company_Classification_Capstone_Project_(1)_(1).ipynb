# %% [markdown]
# <a href="https://colab.research.google.com/github/dis-is-pj/Company-Classification-Capstone-Project/blob/main/Prashant_Jha_Company_Classification_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/AlmaBetter/machine learning/UNSUPERVISED ML/company classification/classification_data11.csv'

# %%
# let's load the data
df = pd.read_csv(path)

# %% [markdown]
# # Exploring the data and null values

# %%
# have a look at the data
df.head()
# Out:
#                   website               company_name  \
# 0         bipelectric.com  bip dipietro electric inc
# 1        eliasmedical.com              elias medical
# 2  koopsoverheaddoors.com       koops overhead doors
# 3         midtowneyes.com            midtown eyecare
# 4     reprosecurity.co.uk         repro security ltd
#
#                                        homepage_text  \
# 0                                       Electrici...
# 1      site map | en español    Elias Medical   h...
# 2      Home  About Us  Garage Door Repair & Servi...
# 3                   918-599-0202        Type Size...
# 4                  Simply fill out our form below...
#
#                                                   h1  \
# 0                                                NaN
# 1  Offering Bakersfield family medical care from ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                   h2  \
# 0                                                NaN
# 1  Welcome to ELIAS MEDICAL#sep#Family Medical Pr...
# 2  Customer Reviews#sep#Welcome to Koops Overhead...
# 3                           Welcome to our practice!
# 4                      Welcome to REPRO SECURITY Ltd
#
#                                                   h3 nav_link_text  \
# 0                                                NaN           NaN
# 1  Get To Know Elias Medical#sep#Family Medical P...           NaN
# 2                                                NaN           NaN
# 3                                                NaN           NaN
# 4                                                NaN           NaN
#
#                                        meta_keywords  \
# 0  electricians vero beach, vero beach electrical...
# 1  Elias Medical bakersfield ca family doctor med...
# 2  Koops Overhead Doors, Albany Garage Doors, Tro...
# 3                                                NaN
# 4                                                NaN
#
#                                     meta_description
# 0  Providing quality, reliable full service resid...
# 1  For the best value in Bakersfield skin care tr...
# 2  Koops Overhead Doors specializes in the sales,...
# 3  We would like to welcome you to Midtown Eyecar...
# 4  Repro Security provide a range of tailor made ...

# %%
# size of data
df.shape
# Out:
# (73974, 9)

# %% [markdown]
# So we have 9 columns in our dataset.

# %%
# null value analysis in each column
df.isnull().sum()
# Out:
# website                 0
# company_name            0
# homepage_text         669
# h1                  27321
# h2                  20762
# h3                  29315
# nav_link_text       25924
# meta_keywords       50302
# meta_description     7088
# dtype: int64

# %%
df.isnull().sum().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# Two columns website and company_name has no null values. Homepage_text also has almost no null values.

# %% [markdown]
# I tried combining h1,h2 and h3 to make 1 column.

# %%
# making a new column by combining h1,h2,h3

df['headings'] = df['h1'].fillna('') + ' ' +df['h2'].fillna('') + ' ' + df['h3'].fillna('')

# %%
# dropping indivisual headings columns
df.drop(['h1','h2','h3'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['website', 'company_name', 'homepage_text', 'nav_link_text',
#        'meta_keywords', 'meta_description', 'headings'],
#       dtype='object')

# %%
# now againg get the idea of null values in rest columns
df[['homepage_text', 'nav_link_text','meta_keywords', 'meta_description']].isnull().sum()
# Out:
# homepage_text         669
# nav_link_text       25924
# meta_keywords       50302
# meta_description     7088
# dtype: int64

# %%
# getting null value distribtuion row wise
df[['homepage_text', 'nav_link_text','meta_keywords', 'meta_description']].isnull().sum(axis=1).value_counts()
# Out:
# 1    44319
# 2    14671
# 0    11660
# 3     2974
# 4      350
# dtype: int64

# %% [markdown]
# In these we see that four columns with 350 rows has all of them missing/null values in those 350 rows. We should remove the rows where at least three of columns are missing/null for a particular row.

# %%
# making a column which has the count of null values in these four columns : 'homepage_text', 'nav_link_text','meta_keywords', 'meta_description'

df['null_count'] = df[['homepage_text', 'nav_link_text','meta_keywords', 'meta_description']].isnull().sum(axis=1)

# %%
# droping the rows with more than three missing values out of the four columns mentioned above
df1 = df[df['null_count']<3]

df1.reset_index(inplace=True, drop=True)

# %%
df1.shape
# Out:
# (70650, 8)

# %%
df1.columns
# Out:
# Index(['website', 'company_name', 'homepage_text', 'nav_link_text',
#        'meta_keywords', 'meta_description', 'headings', 'null_count'],
#       dtype='object')

# %%
# dropping the 'null_count' column
df1.drop('null_count', axis=1, inplace=True)
# Out:
# <ipython-input-20-70b7a9a94c93>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop('null_count', axis=1, inplace=True)

# %%
df1
# Out:
#                       website               company_name  \
# 0             bipelectric.com  bip dipietro electric inc
# 1            eliasmedical.com              elias medical
# 2      koopsoverheaddoors.com       koops overhead doors
# 3             midtowneyes.com            midtown eyecare
# 4         reprosecurity.co.uk         repro security ltd
# ...                       ...                        ...
# 70645          nayyarsons.com            nayyarsons food
# 70646  claddaghcoffeecafe.com            claddagh coffee
# 70647    beautyologist.com.au              beautyologist
# 70648        beautycall.co.uk                beauty call
# 70649     littleladyfoods.com          little lady foods
#
#                                            homepage_text  \
# 0                                           Electrici...
# 1          site map | en español    Elias Medical   h...
# 2          Home  About Us  Garage Door Repair & Servi...
# 3                       918-599-0202        Type Size...
# 4                      Simply fill out our form below...
# ...                                                  ...
# 70645
# 70646                       Home    About Us    Our S...
# 70647                                  03 9531 5092 M...
# 70648                                                ...
# 70649                                                ...
#
#                                            nav_link_text  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 70645                                                NaN
# 70646                                                NaN
# 70647  shop,e-vouchers,by category,bath & body,candle...
# 70648                     gallery,prices,reviews,artists
# 70649  what we do,our partners,why choose us,our fami...
#
#                                            meta_keywords  \
# 0      electricians vero beach, vero beach electrical...
# 1      Elias Medical bakersfield ca family doctor med...
# 2      Koops Overhead Doors, Albany Garage Doors, Tro...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 70645            Nayyarsons, Deli, Bakery, Food Services
# 70646  Claddagh Coffee Cafe, Saint Paul, St. Paul, Mi...
# 70647                                                NaN
# 70648                                                NaN
# 70649                                                NaN
#
#                                         meta_description  \
# 0      Providing quality, reliable full service resid...
# 1      For the best value in Bakersfield skin care tr...
# 2      Koops Overhead Doors specializes in the sales,...
# 3      We would like to welcome you to Midtown Eyecar...
# 4      Repro Security provide a range of tailor made ...
# ...                                                  ...
# 70645  Nayyarsons Corporation offical website and por...
# 70646  Claddagh Coffee Cafe, located in Saint Paul, M...
# 70647  Advanced skin therapists with post grad qualif...
# 70648  Beauty Call can arrange a local, mobile, profe...
# 70649  Miracapo develops and manufactures high qualit...
#
#                                                 headings
# 0
# 1      Offering Bakersfield family medical care from ...
# 2       Customer Reviews#sep#Welcome to Koops Overhea...
# 3                              Welcome to our practice!
# 4                         Welcome to REPRO SECURITY Ltd
# ...                                                  ...
# 70645
# 70646                                                 ​
# 70647  Beautyologist Beauty Salon Welcome to Beautyol...
# 70648  Mobile Hair & Makeup Artists across the UK Why...
# 70649  Discover, Innovate, Execute, Enjoy! Pizza is o...
#
# [70650 rows x 7 columns]

# %% [markdown]
# Now we will combine the text information from all the columns into a single column

# %%
# before combining the columns
# we need to replace null values with empty strings
df1.fillna('', inplace=True)
# Out:
# <ipython-input-22-611efd001f8c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.fillna('', inplace=True)

# %%
df1
# Out:
#                       website               company_name  \
# 0             bipelectric.com  bip dipietro electric inc
# 1            eliasmedical.com              elias medical
# 2      koopsoverheaddoors.com       koops overhead doors
# 3             midtowneyes.com            midtown eyecare
# 4         reprosecurity.co.uk         repro security ltd
# ...                       ...                        ...
# 70645          nayyarsons.com            nayyarsons food
# 70646  claddaghcoffeecafe.com            claddagh coffee
# 70647    beautyologist.com.au              beautyologist
# 70648        beautycall.co.uk                beauty call
# 70649     littleladyfoods.com          little lady foods
#
#                                            homepage_text  \
# 0                                           Electrici...
# 1          site map | en español    Elias Medical   h...
# 2          Home  About Us  Garage Door Repair & Servi...
# 3                       918-599-0202        Type Size...
# 4                      Simply fill out our form below...
# ...                                                  ...
# 70645
# 70646                       Home    About Us    Our S...
# 70647                                  03 9531 5092 M...
# 70648                                                ...
# 70649                                                ...
#
#                                            nav_link_text  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 70645
# 70646
# 70647  shop,e-vouchers,by category,bath & body,candle...
# 70648                     gallery,prices,reviews,artists
# 70649  what we do,our partners,why choose us,our fami...
#
#                                            meta_keywords  \
# 0      electricians vero beach, vero beach electrical...
# 1      Elias Medical bakersfield ca family doctor med...
# 2      Koops Overhead Doors, Albany Garage Doors, Tro...
# 3
# 4
# ...                                                  ...
# 70645            Nayyarsons, Deli, Bakery, Food Services
# 70646  Claddagh Coffee Cafe, Saint Paul, St. Paul, Mi...
# 70647
# 70648
# 70649
#
#                                         meta_description  \
# 0      Providing quality, reliable full service resid...
# 1      For the best value in Bakersfield skin care tr...
# 2      Koops Overhead Doors specializes in the sales,...
# 3      We would like to welcome you to Midtown Eyecar...
# 4      Repro Security provide a range of tailor made ...
# ...                                                  ...
# 70645  Nayyarsons Corporation offical website and por...
# 70646  Claddagh Coffee Cafe, located in Saint Paul, M...
# 70647  Advanced skin therapists with post grad qualif...
# 70648  Beauty Call can arrange a local, mobile, profe...
# 70649  Miracapo develops and manufactures high qualit...
#
#                                                 headings
# 0
# 1      Offering Bakersfield family medical care from ...
# 2       Customer Reviews#sep#Welcome to Koops Overhea...
# 3                              Welcome to our practice!
# 4                         Welcome to REPRO SECURITY Ltd
# ...                                                  ...
# 70645
# 70646                                                 ​
# 70647  Beautyologist Beauty Salon Welcome to Beautyol...
# 70648  Mobile Hair & Makeup Artists across the UK Why...
# 70649  Discover, Innovate, Execute, Enjoy! Pizza is o...
#
# [70650 rows x 7 columns]

# %%
# making single columns with all text information
# separated by space
df1['text'] = df1['homepage_text'] + ' ' + df1['nav_link_text'] + ' ' + df1['meta_keywords'] + ' ' + df1['meta_description'] + ' ' + df1['headings']
# Out:
# <ipython-input-24-1ca58417fd60>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['text'] = df1['homepage_text'] + ' ' + df1['nav_link_text'] + ' ' + df1['meta_keywords'] + ' ' + df1['meta_description'] + ' ' + df1['headings']

# %%
# Making a separate dataframe with website,company name and text column which has all the text info
df2 = df1[['website', 'company_name', 'text']]

# %%
df2.shape
# Out:
# (70650, 3)

# %%
df2.tail()
# Out:
#                       website       company_name  \
# 70645          nayyarsons.com    nayyarsons food
# 70646  claddaghcoffeecafe.com    claddagh coffee
# 70647    beautyologist.com.au      beautyologist
# 70648        beautycall.co.uk        beauty call
# 70649     littleladyfoods.com  little lady foods
#
#                                                     text
# 70645            Nayyarsons, Deli, Bakery, Food Servi...
# 70646                       Home    About Us    Our S...
# 70647                                  03 9531 5092 M...
# 70648                                                ...
# 70649                                                ...

# %% [markdown]
# ## Searching/Checking if special characters are present in our dataset

# %%
s = 'abcdefghijklmnopqrstuvwxyz ABCDEFGHIJKLMNOPQRSTUVWXYZ'
specials = set()

# %%
for text in df2['text']:
    for c in text:
        if c not in s:
            specials.add(c)

# %%
for special in specials:
    print(special[:2000])
# Out:
# Streaming output truncated to the last 5000 lines.
# ］
# 󠁮
# ➔
# 舍
# ෂ
# 専
# 痛
# 〓
# 妻
# 哪
# Т
# 话
# 𝐥
# 🍒
# 巧
# ฮ
# 昊
# 
# 鲣
# 坐
# 物
# 绕
# 
# ━
# 團
# ӣ
# 纪
# 榉
# 🎆
# ↟
# ക
# 捞
# 飾
# 
# ɔ
# 價
# ं
# ِ
# 
# 속
# 潼
# 吟
# 恩
# ি
# 른
# ೈ
# Õ
# 
# 
# 馬
# 衔
# 🏢
# 
# ఫ
# 휘
# ド
# 厕
# 🎃
# 犹
# 届
# 呆
# 
# 仝
# 臻
# Є
# 簽
# 齢
# 犬
# Ｄ
# 록
# 
# ـ
# 
# 售
# よ
# 烽
# 십
# 滨
# 배
# 畔
# 腿
# 熟
# 旬
# 岁
# ì
# 尻
# 作
# 楷
# േ
# 紫
# 肾
# 創
# 词
# ል
# ට
# 谢
# 院
# 宿
# 
# ʃ
# 先
# ¬
# 까
# 額
# 纯
# 외
# এ
# 马
# 략
# 他
# 辆
# 🗺
# 북
# 騷
# ദ
# 贾
# ী
# 🔍
# 회
# 솔
# 哦
# 姆
# 
# 邮
# Δ
# 巫
# 
# 𝘂
# 련
# ✰
# Έ
# 欲
# 
# 宏
# 𝙬
# 
# 丁
# 彩
# 蔓
# 烟
# 红
# 設
# 頂
# 프
# 깨
# デ
# 周
# 坎
# 并
# வ
# 腐
# 徴
# 芜
# ｘ
# ใ
# 曼
# 车
# 儿
# ぐ
# 圳
# 📠
# ▴
# ë
# 就
# ､
# 살
# ͜
# 莎
# θ
# щ
# γ
# 嘲
# ပ
# ∙
# 𝗦
# 
# ‏
# 
# 塗
# 
# ነ
# 雾
# 알
# 妈
# 📰
# 贵
# 釣
# 紀
# ェ
# 奶
# 😢
# 🤖
# 呈
# 🔒
# 事
# 🤑
# 
# 느
# घ
# 夥
# ﺭ
# 洋
# 🍫
# 温
# ኣ
# 町
# 缩
# ஓ
# 哀
# 🚪
# 廖
# 🍌
# 🗝
# 累
# 니
# 💐
# 
# 
# 拜
# ס
# 
# 索
# 考
# 
# 
# 击
# 柔
# 
# 産
# 颗
# 〖
# 墓
# 跑
# 涪
# 표
# ޭ
# 薄
# 归
# 𝐛
# 晨
# 係
# ਼
# 🚘
# 把
# 钱
# 邦
# 傷
# 页
# 萃
# バ
# 锲
# Հ
# 喜
# 淮
# ã
# 炬
# な
# ⋅
# 趋
# 猜
# 史
# に
# ொ
# Η
# 併
# 🇲
# у
# 舫
# 列
# 裁
# 改
# 珈
# ἔ
# $
# 闪
# ュ
# –
# 呑
# 🥧
# 
# 总
# 𝐯
# 铼
# П
# 尾
# 椿
# 棴
# 业
# 在
# ε
# 狱
# 원
# 尉
# 警
# í
# 違
# 赠
# 扶
# 詹
# 
# 诉
# 辱
# Ⅰ
# 离
# 甲
# 乱
# 邓
# 裏
# 
# 碎
# 殖
# ？
# 利
# 忽
# 扱
# ァ
# ὴ
# 繳
# ゴ
# ซ
# 亂
# 陽
# ⅔
# 
# 我
# ソ
# 
# 館
# ₦
# 煤
# 奔
# 极
# 히
# ส
# 
# 钴
# 軟
# 贴
# 셜
# 
# 凝
# 😊
# 右
# 
# 凸
# ໍ
# 状
# 异
# 河
# 秩
# 暑
# 攀
# 
# พ
# ⁵
# ま
# 孟
# 項
# į
# 老
#
#
# 峡
# ウ
# 区
# ố
# 議
# グ
# ậ
# 受
# ન
# 訳
# 娜
# 财
# 擦
# 🧳
# 
# 杨
# 郝
# 🥣
# ẽ
# 死
# ✊
# 剩
# 陆
# ч
# 艳
# 粋
# 汁
# 
# 📮
# 컬
# ɡ
# 册
# 纤
# 麗
# ዮ
# 
# 
# 杭
# 
# 骏
# ◢
# 灯
# 됩
# 
# ൗ
# 문
# 
# 타
# 🏾
# ↺
# 活
# 勋
# 附
# 店
# 錄
# ン
# 📣
# 肯
# ة
# 僕
# 険
# ⊙
# 🏚
# 涨
# 民
# ê
# ው
# •
# 烂
# Α
# 🇳
# 耐
# 戎
# 澳
# 计
# ヒ
# ಎ
# 젝
# 昔
# 炮
# 港
# 
# 
# 默
# ಏ
# 
# 剰
# ÷
# 분
# 
# 煎
# :
# 绳
# 𝐞
# 炸
# 窗
# 废
# 따
# 𝙨
# ✩
# 続
# ಿ
# 🐹
# Į
# 香
# 
# カ
# ಳ
# 祉
# 装
# 鍋
# 肘
# Ÿ
# 錘
# ⤵
# 浸
# 說
# 󰀉
# 患
# 験
# 𝙞
# 荧
# 秘
# 內
# ௌ
# 銘
# 镑
# 认
# 
# 还
# 影
# ️
# 
# ქ
# ū
# 행
# А
# ✮
# ಹ
# み
# ò
# 
# ☆
# 
# ና
# 唐
# 檢
# 登
# ቶ
# ණ
# ط
# 長
# ―
# 🇾
# 9
# Ā
# ﯽ
# 🇯
# 
# 猪
# 
# Н
# 蒙
# 玩
# 
# 
# 🍨
# 妄
# 🥩
# 든
# 國
# Í
# 良
# 變
# 脉
# 柳
# 撮
# 都
# 스
#
# 票
# 扎
# 實
# ︎
# ◌
# 屈
# Յ
# ਜ
# ズ
# ｌ
# 难
# 販
# ⛔
# ह
# ੁ
# 衫
# 敌
# ீ
# 엄
# 远
# 硫
# ※
# ぎ
# 畏
# 
# 视
# ရ
# 低
# 抽
# 缝
# 祿
# 
# ᴹ
# ฒ
# 
# 宴
# 肤
# ③
# 沟
# 
# 
# 捧
# 담
# 処
# 腹
# 합
# 挂
# ര
# 建
# 이
# 飙
# 亦
# ➖
# 寸
# 歧
# 馄
# 𝐚
# 🏏
# 畅
# 👇
# 偽
# 럴
# ﺣ
# 🖌
# 
# 牢
# 
# 현
# 
# ͛
# 𝗸
# 것
# ✯
# 🏘
# 球
# 𝐟
# ⇒
# 怕
# ॉ
# 더
# 𝐨
# 员
# 品
# ண
# 以
# 强
# 核
# 捷
# 🍑
# 某
# 服
# 페
# 凡
# ﾚ
# ਪ
# 帖
# 避
# 惮
# ዎ
# 羁
# ¾
# 🌇
# び
# ̄
# 🏗
# ۔
# ѕ
# 
# 双
# 
# ิ
# 
# Р
# 篇
# ौ
# 
# 
# 眠
# 
# 画
# 鞋
# 吊
# 潤
# 𝗔
# 损
# ܼ
# ์
# ぱ
# 程
# 陶
# ώ
# ೆ
# ¼
# 🄷
# 🌟
# ो
# ю
# 動
# 细
# ੂ
# त
# 純
# 娅
# 🍍
# 濡
# 世
# 阪
# 罢
# ၱ
# 특
# 
# 断
# 傅
# ్
# 秋
# 😷
# 竣
# 總
# 臨
# ☝
# 
# 漂
# 問
# ̀
# タ
# 
# 结
# 兆
# 메
# ̉
# ＇
# 
# 留
# 
# 擬
# ফ
# ည
# ೌ
# 😉
# 瑞
# 岔
# 伴
# 렸
# 🧛
# 復
# 𝗛
# ष
# 較
# 够
# Ş
# 界
# ભ
# 憶
# 數
# 
# 裝
# 划
# 存
# 钨
# 蒂
# 艦
# 疫
# 
# 菏
# ̣
# 🦅
# ￡
# 藤
# ά
# 𝘆
# 隨
# 
# 𝐃
# ऋ
# У
# ▿
# ⚖
# 奉
# ▹
# 
# 沿
# 练
# ̧
# 氨
# 刀
# ｓ
# 党
# 搏
# ུ
# 但
# 浒
# 秦
# 旁
# 阳
# 这
# ф
# 枫
# 妇
# 쌤
# が
# 伟
# 
# 좋
# 𝗿
# 撰
# 锥
# 을
# ų
# 池
# 免
# 聊
# ᵒ
# 挖
# 註
# ਗ
# 
# 迁
# 拡
# Ｎ
# 潍
# ￼
# 📬
# ﷻ
# 喀
# 酸
# ể
# ́
# 로
# 勉
# ν
# 波
# 
# {
# 당
# œ
# 🥁
# 剧
# 秉
# 牵
# 
# ต
# 
# 捉
# Ř
# 亍
# ặ
# 勤
# 泌
# 
# ०
# 
# 御
# ከ
# 
# 誰
# 健
# 柱
# 官
# 圍
# ロ
# 
# ả
# 
# 
# 湃
# 向
# 岳
# 砍
# 枝
# 播
# 𝐤
# 
# 발
# ＼
# ஏ
# 
# 豹
# 🧘
# 锁
# 
# ④
# ധ
# ި
# б
# 😘
# 
# 违
# 亏
# ස
# Ấ
# ח
# 姿
# జ
# 噬
# ľ
# 
# ５
# 苏
# ◁
#
# 移
# 
# 助
# 碳
# 정
# 
# 🤝
# 閉
# ❱
# 绝
# ರ
# ম
# 执
# 惨
# 義
# 廉
# 畳
# 兄
# 咔
# ਲ
# 础
# 樓
# 询
# 拾
# ‡
# 榜
# 글
# 又
# 郊
# ُ
# 慑
# 努
# 
# 복
# 🔎
# 拠
# 오
# 韵
# ִ
# 因
# 雇
# 
# ઇ
# Ц
# 夜
# 熬
# 
# 🏁
# 𝗖
# 勃
# 岛
# 🐱
# 별
# ℃
# ほ
# 😐
# ệ
# ጥ
# 类
# כ
# ગ
# 𝐓
# 蜀
# ぶ
# 
# 首
# હ
# ｍ
# 
# 送
# 🍏
# 兼
# Á
# 泣
# ш
# 择
# 里
# ค
# プ
# ὥ
# 研
# 様
# 値
# 
# 𝗴
# 该
# 
# ڌ
# û
# ᵗ
# Ä
# ഓ
# 求
# 💲
# 疹
# ℹ
# Ý
# 安
# 跟
# 黛
# 
# 
# 咖
# 
# 막
# 𝙈
# 􀃶
# Å
# 痫
# 给
# ♦
# 锚
# 裔
# 単
# づ
# 陵
# ಫ
# 卢
# ْ
# 
# 抗
# ⁦
# 년
# 🇩
# 奨
# 恶
# ゥ
# 窓
# ■
# ﹏
# 帅
# 출
# 🍁
# প
# 
# 製
# ַ
# ྲ
# 渗
# 姚
# 
# 💘
# 圧
# 献
# 扑
# 2
# 绘
# ᶻ
# 🙊
# 継
# 戈
# 驱
# 漬
# ự
# 翅
# ὲ
# 甜
# 켓
# ﾏ
# Л
# ⟵
# ｽ
# 库
# 
# Ｉ
# 
# 🎦
# 沐
# 掃
# 추
# 掲
# 󰀑
# 仓
# ी
# 
# 胺
# ➚
# ̃
# 
# ಟ
# 咒
# 鸽
# চ
# 瞳
# 担
# 房
# 藏
# 毁
# 挑
# τ
# 
# 
# 泉
# 🤩
# 怒
# 苗
# ア
# 释
# ҷ
# 泪
# ケ
# 
# 🌷
# 𝐇
# 
# 增
# 🎥
# ء
# े
# 障
# 乡
# 别
# 
# റ
# ⇛
# 邯
# 심
# 之
# 曝
# ￾
# 鸦
# 씩
# ื
# 
# ◾
# 
# 
# ẫ
# 讓
# 回
# 暴
# ע
# 菱
# 🌎
# 
# 雄
# 令
# ą
# 甚
# ⋮
# ►
# 
# 🍷
# 떻
# 🎈
# ങ
# 📫
# ồ
# 羊
# ම
# ಘ
# !
# 簡
# 対
# Ù
# ☷
# 版
# 鸡
# 𝗺
# 環
# 仇
# 母
# 银
# 
# 膝
# 
# ▷
# 辉
# 汇
# з
# 阿
# 計
# 髯
# 〜
# 재
# ひ
# 𝗳
# ⬇
# ي
# 
# Ο
# 购
# 孕
# 蓬
# ट
# 腾
# 👩
# 🥑
# 🌬
# 质
# α
# ऱ
# 跻
# 
# জ
# 
# э
# 週
# ״
# И
# 旺
# 嵐
# 嗨
# п
# 듀
# 隈
# ത
# 𝗵
# 布
# 辰
# 饭
# ൽ
# 
# ż
# 鼻
# 
# 博
# 提
# 🙌
# ␡
# 稿
# 
# 여
# 會
# ս
# 
# 粮
# 棋
# ث
# 
# ā
# 基
# 按
# 薪
# 女
# 芬
# 遭
# 乐
# 😒
# 筛
# 杆
# 진
# ủ
# य
# 疑
# 貴
# 烤
# འ
# 愛
# 輯
# 📶
# መ
# 목
# ]
# 
# β
# ∂
# 役
# 인
# 芙
# 严
# 還
# 省
# 属
# Б
# ་
# 積
# 𝗬
# 综
# 斤
# ភ
# 🔐
# ‒
# 轄
# 涯
# 🍴
# ⇩
# 🗑
# Ы
# ੰ
# 𝐋
# 舉
# 
# 🥺
# ม
# 🇿
# 央
# д
# 弈
# ਸ
# 💃
# 闭
# 目
# ე
# 悻
# 
# 露
# 屌
# झ
# 縄
# 가
# 侮
# ه
# 弊
# 當
# ̵
# ✦
# 茫
# 闺
# 鸿
# 盲
# め
# 𝐅
# 編
# 脏
# 경
# ظ
# 
# 粗
# 🐾
# 🍯
# 丙
# 層
# 
# 🚚
# 벤
# 
# 另
# ዋ
# 仪
# ె
# 員
# ✓
# ⅜
# 勿
# ལ
# 户
# 
# ə
#
# 겁
# 胞
# 🌿
#
# 瑟
# ප
# 면
# 魏
# Г
# 悩
# Φ
# 霆
# 旭
#
# ⛌
# 
# ț
# ̷
# ʌ
# 拔
# 琐
# 膜
# უ
# 래
# 騒
# 
# 億
# थ
# 恢
# }
# 鹕
# 越
# 托
# 張
# 🚵
# 
# ო
# 약
# 집
# 竖
# ǁ
# 💛
# ؤ
# 🥪
# 斥
# 恰
# ノ
# 喘
# 
# 🧁
# 铲
# 餌
# 🤶
# ʟ
# 
# 种
# 绍
# 💣
# 驰
# 🖼
#
# 쿠
# 掌
# 讼
# 🍈
# 擒
# 
# 
# ◤
# 움
# 尊
# 
# 校
# ജ
# ស
# 沂
# 
# 乙
# 🍋
# ජ
# ञ
# 苦
# 🕊
# 虫
# 吉
# 纸
# 身
# 缺
# 
# 
# 源
# 帓
# 于
# 衡
# 위
# 慎
# 养
# 伍
# 공
# 했
# ්
# 凯
# 恨
# 다
# 铝
# ξ
# 巩
# 
# 🤔
# ญ
# െ
# ٠
# 던
# 
# └
# 飘
# 規
# 馒
# গ
# 〈
# 岆
# ޖ
# Е
# 阙
# Ψ
# 止
# 仮
# 𝟑
# 입
# າ
# 鹏
# 
# 
# 佳
# ≻
# ҫ
# 囡
# 依
# 等
# 昂
# 𝙛
# 
# 诣
# ￫
# య
# 
# 
# 苟
# 
# ὐ
# 雕
# ុ
# 잡
# 签
# 屁
# 陕
# ė
# ਣ
# 奥
# 🤤
# 嵌
# 判
# ☁
# ̋
# 滋
# 袜
# 🌲
# 제
# 非
# 
# ˚
# 💎
# 涂
# ‌
# 💨
# 
# 瘫
# ﹀
# ♣
# Й
# 데
# 单
# 「
# 沈
# 逼
# 𝙖
# 麼
# 候
# ̓
# 园
# 辨
# Ę
# 𝐊
# 👎
# ♨
# 🏅
# 叉
# 场
# പ
# 済
# 季
# 臀
# ့
# 
# 懊
# Ö
# پ
# 💠
# 互
# 
# 
# 
# 幼
# ✻
# 
# ♡
# ು
# 靳
# 恋
# 🙋
# 👙
# 紙
# 啊
# 
# 嫩
# מ
# ع
# 复
# ำ
# ም
# യ
# Ｌ
# 
# *
# 
# 丹
# 
# 강
# 歴
# ှ
# 及
# 髦
# ා
# 舌
# ｖ
# 错
# ת
# 🏼
# 且
# 格
# 柏
# 📜
# ᴇ
# 양
# 😍
# 筑
# 卻
# ἤ
# 论
# ❯
# 伦
# 絡
# 厘
# 々
# 线
# 仔
# 
# ł
# ഉ
# 崎
# ວ
# 厮
# 📢
# 貰
# け
# ள
# ❆
# 勝
# ন
# 舊
# 富
# 翘
# 르
# 👨
# 𝐈
# ب
# 钞
# 
# 铸
# 屑
# 미
# ී
# 場
# 仿
# 娇
# 
# 
# す
# 
# 𝗯
# ᴡ
# 庞
# 芝
# 租
# 救
# 
# 串
# 起
# ե
# ι
# 泡
# 🕓
# 
# 島
# ச
# ಗ
# 桌
# 🔁
# 
# 镜
# 赫
# 治
# 須
# 
# 桑
# 寅
# 
# 誕
# 顶
# 脸
# 席
# ඩ
# 유
# ん
# 繼
# 많
# 
# 📦
# ج
# ⇓
# 夺
# 挺
# %
# 橋
# 厨
# 체
# テ
# 素
# き
# 客
# 欧
# 侣
# 顧
# 驻
# げ
# အ
# 달
# 思
# 
# 碰
# ជ
# 
# 验
# 憾
# 用
# 窑
# 聖
# 🍅
# 📽
# 
# 査
# 溃
# 佑
# 狠
# 
# 進
# 预
# 肢
# 준
# 那
# و
# 吧
# 嘘
# 钼
# 📊
# 👴
# 浅
# 𝘧
# 複
# /
# 尖
# 详
# ព
# 子
# ❝
# 
# 乒
# 資
# 精
# 二
# ú
# 此
# 컨
# 颜
# 萎
# ŋ
# 
# Ｖ
# ⏲
# 
# 奷
# 어
# ў
# 넥
# 题
# 없
# 浙
# 박
# ň
# ẩ
# 须
# 擴
# 泊
# Ã
# 
# 拥
# 汰
# ◊
# 骤
# 蚂
# 告
# 洒
# 👆
# 演
# 🎇
# 咳
# 🌴
# 鮎
# 弗
# 録
# 弱
# 
# り
# 🦔
# 桓
# ြ
# ☐
# 🇶
# 付
# 🏳
# 
# 杜
# ಷ
# 故
# 💁
# 
# 하
# 
# 范
# 
# 齿
# 𝟐
# 
# 忍
# ጻ
# 
# 補
# 准
# 肺
# ✪
# ਹ
# 获
# 名
# ☞
# ⚠
# 番
# 轰
# 骼
# 
# 弓
# 도
# 
# 激
# 
# 譯
# र
# 
# 慕
# 😭
# 
# 橄
# 慮
# 畜
# 哥
# ヌ
# 무
# 礼
# 韦
# 戻
# ü
# 软
# 負
# 猛
# 键
# 𝐌
# 隶
# 結
# 衰
# 搜
# 
# 广
# 梗
# ⚾
# 乖
# 搓
# 
# 
# 戶
# λ
# ⠀
# 部
# 〒
# 
# 操
# ⇑
# 揽
# 論
# 稚
# 🦘
# ആ
# ܬ
# 肥
# 字
# ポ
# ¸
# 文
# 텍
# 
# 洁
# 於
# は
# 辕
# É
# 理
# 萨
# 謝
# 翔
# 🏭
# 幽
# 𝐀
# ̦
# ๆ
# 對
# 🚴
# 𝐳
# 栖
# 各
# 𝙚
# ,
# ऊ
# 毅
# 課
# 下
# 서
# ಪ
# 😯
# 磨
# 琼
#
# న
# 
# 姐
# 🤓
# 专
# 珍
# 夸
# 煷
# 摩
# 钙
# 工
# 输
# 条
# 钓
# ಲ
# 父
# 券
# 滕
# ▸
# 框
# 检
# ứ
# 酮
# ●
# 💖
# 胴
# 
# 營
# ぷ
# 偶
# 糊
# 王
# 没
# 點
# ©
# ฎ
#
# 苑
# 
# 值
# Û
# ｿ
# 内
# 聘
# 烯
# 永
# 
# 
# 輸
# 耀
# 宽
# 편
# 
# 💕
# 
# 綿
# 음
# 綺
# ذ
# இ
# 将
# 果
# 維
# 瞬
# ဥ
# 遍
# 실
# 纵
# 
# ś
# 淼
# 松
# 簿
# ే
# ய
# 맨
# 钾
# 埋
# ʼ
#
#
# 戒
# 
# え
# ʏ
# ἢ
# 胸
# 然
# 睐
# Æ
# 能
# 
# 烦
# ば
# 
# 坚
# 켈
# 
# פ
# 끼
# 등
# া
# 洧
# 겠
# 察
# 輿
# 长
# 印
# ×
# 胡
# ◐
# 순
# 료
# 揺
# 究
# 陞
# 琰
# 羚
# 李
# ￬
# 剤
# 🛥
# 耳
# 渉
# ě
# 𝙎
# 파
# 瓦
# 骁
# 缚
# 修
# 遅
# ◄
# ლ
# 浇
# 灵
# 片
# 磁
# 氯
# ೕ
# 気
# ↠
# 著
# 據
# 墅
# 機
# 関
# 깔
# 標
# 
# 痹
# 蛮
#
# 黎
# 🐮
# બ
# 
# 抓
# 堤
# 吓
# ｄ
# ब
# 魚
# ἵ
# 
# ￿
# 鸟
# 牝
# 🏒
# 伺
# 🌀
# 軍
# ง
# ☕
# 디
# 敢
# 
# 舟
# 滓
# 
# 害
# 
# Σ
# ű
# 赔
# Â
# 积
# 骚
# 孚
# ◀
# 郁
# 咱
# 類
# 💫
# 🌼
# 匹
# 🌥
# 
# 哑
# ‰
# 才
# 规
# 화
# 万
# 拒
# 堆
# ો
# 케
# ⚪
#
# 兴
# 판
# 紧
# 
# 诠
# ぼ
# ỷ
# Ê
# 🙉
# 无
# 株
# 箸
# 临
# 也
# 첨
# 排
# 🔆
# 
# 耶
# 再
# ữ
# 慶
# 
# 
# ３
# う
# 郑
# Ω
# 援
# 刚
# 丢
# 最
# ੀ
# ῆ
# 루
# ഥ
# ｏ
# 渣
# 핵
# ಾ
# 
# 迄
# 🍹
# 𝐰
# ะ
# 尚
# 団
# 散
# 九
# 初
# 
# 侵
# د
# ね
# 》
# 迪
# а
# 僮
# ی
# 🏀
# ೋ
# 𝟖
# 
# 反
# ń
# 
# 零
# ،
# ಸ
# ೀ
# م
# 奋
# 降
# 叭
# 楽
# 😱
# ழ
# භ
# 知
# 队
# 단
# ठ
# ∞
# 
# 惹
# 雁
# ✏
# ð
# ⟶
# 珀
# 护
# 饲
# 〕
# 椅
# 缸
# 盈
# 歪
#
# 趣
# 磯
# ⬣
# ግ
# ̩
# 💥
# 顔
# 茨
# ს
# 繋
# 木
# 迷
# 🍝
# 費
# 公
# 益
# น
# 歩
# ź
# 
# 坦
# ス
# ゲ
# 旅
# 騰
# 图
# 
# 定
# ✔
# 🚌
# 맛
# 應
# ム
# 僚
# ₺
# 屏
# 
# ṭ
# 德
# 束
# 釈
# 家
# 叔
# 滥
# ދ
# 織
# ゾ
# 蔵
# 虎
# 艾
# 愿
# 𝗲
# 
# ➸
# 婚
# ⬤
# 
# 
# 
# 幻
# 
# 🕶
# ぬ
# く
# 
# 砚
# 
# ς
# 衣
# ❜
# л
# ᴠ
# થ
# 線
# ‟
# ⊕
# ö
# ⚬
# ँ
# 퍼
# 挪
# 🔥
# 管
# 🔽
# 聞
# ί
# 𝗪
# 
# ｐ
# ＋
# 诱
# 🇻
# 
# 涌
# Ế
# 鼔
# ʀ
# õ
# 倍
# 支
# 仆
# 术
# 華
# ď
# 書
# 吁
# Ľ
# ോ
# 
# 村
# 肋
# 见
# ተ
# ~
# ό
# 
# 特
# 嘱
# 功
# 碍
# ☣
# 🍊
# 盗
# 🎿
# ⁷
# ਚ
# 美
# 
# ✴
# ％
# 嗜
# 
# ũ
# ¡
# 콘
# 」
# 瞿
# 😄
# 寻
# 乎
# 취
# 鼠
# 통
# 體
# 族
# 績
# ה
# 训
# 怀
# 婴
# 侗
# ɖ
# 
# 痒
# 菠
# Ж
# ত
# Ğ
# 振
# ，
# ਸ਼
# 式
# 镁
# 
# 😳
# 液
# 韓
# 至
# 巴
# 
# 😟
# 狙
# ふ
# 
# 慢
# 擇
# 玛
# 
# ன
# 鞭
# 乌
# 
# 🥰
# 🦄
# 🕺
# 리
# т
# 
# 殿
# 廻
# ሻ
# 
# 覧
# ฟ
# 末
# ◈
# 🍳
# 𝐮
# ⇧
# 忆
# 仙
# 蜂
# ހ
# シ
# 凭
# ↪
# で
# 
# 💍
# ज
# 🦁
# 架
# ≪
# 👻
# Ｘ
# 湿
# ｕ
# 医
# 拆
# 効
# 
# 빠
# 🌐
# 较
# ం
# 
# 渔
# 濯
# 🧠
# ൾ
# 葩
# ǒ
# 返
# 👊
# 廈
# 割
# ジ
# ف
# ں
# 亵
# 尺
# 후
# 辖
# 족
# 随
# 🍰
# 胃
# 🍪
# 🥥
# 語
# 𓆈
# 关
# 融
# 🗄
# ⑦
# )
# 笑
# 
# 채
# 慣
# 诊
# 
# 평
# 權
# ָ
# 🌭
# 拓
# 冕
# 分
# 
# 반
# 柴
# 嫉
# 真
# 徐
# 極
# 阻
# ஞ
# 机
# @
# 
# 紹
# 욕
# 
# 拍
# 獲
# 童
# 允
# 
# ו
# Ɂ
# 
# 馆
# 堡
# 运
# ❣
# 며
# 談
# 手
# ቁ
# ❂
# 환
# ਆ
# 编
# 惡
# 🐟
# 晒
# ¯
# ⌄
# 现
# 
# 💓
# 
# 务
# 癫
# 🇽
# 诛
# 斩
# 
# 🏋
# 箱
# 社
# 방
# 踪
# 𝗰
# 润
# 刻
# 즐
# 
# ⁩
# 仲
# 涉
# 
# 珊
# 围
# র
# 萄
# 陋
# て
# 트
# 浜
# Ò
# 김
# 杉
# 姑
# 希
# ấ
# ρ
# 
# Î
# ͞
# 澎
# 柄
# আ
# 態
# 日
# 記
# 撥
# 択
# 叫
# 🌱
# 涿
# 常
# 氏
# ם
# 产
# 偿
# ［
# 领
# 
# 拧
# 静
# 
# 差
# ⨯
# 径
# 立
# 🤞
# 
# ﾗ
# 负
# ラ
# 叮
# 备
# 载
# 音
# 결
# 羞
# 五
# ਰ
# Ų
# 
# 
# 軽
# ू
# 爵
# 초
# 跆
# 含
# 큰
# 莓
# ग
# ጅ
# 🎶
# 🤭
# ड़
# 配
# ℠
# ஹ
# 💝
# 跨
# 算
# 사
# 戸
# 
# 淛
# 碑
# ፡
# 財
# 👦
# 彻
# 
# 未
# 🏴
# 破
# 八
# 糟
# 为
# 杯
# ં
# 
# 
# 저
# 절
# 宁
# 酯
# 擅
# 中
# 浄
# 盼
# Ｈ
# 脊
#
# 처
# ý
# 🡒
# 溯
# £
# ꟷ
# 
# 善
# ô
# 𝐍
# ƒ
# š
# ਧ
# သ
# 峪
# ͚
# 🌯
# 🥯
# 砂
# 旋
# 吹
# 
# 讯
# 始
# ﻳ
# ಉ
# ち
# 铜
# 抛
# ▾
# 汎
# 
# 
# 𝙧
# 傾
# 肉
# 射
# 州
# 书
# 
# ≠
# Я
# 耗
# 󰀛
# 屹
# 猥
# ृ
# 🌡
# 紋
# 膏
# 器
# 毓
# 春
# 無
# 🖐
# 
# 荒
# 旦
# 품
# 각
# า
# ု
# 颤
# ‾
# ご
# 蛇
# 작
# 📸
# 
# ろ
# 巅
# 찾
# ൺ
# 庙
# 🙄
# 🎟
# 逆
# த
# 邻
# 
# Ș
# ᴘ
# 農
# 
# 尼
# 𝗷
# ✎
# 应
# 沉
# 천
# 帆
# 痊
# 期
# △
# 
# 
# 
# 楚
# 
# ჻
# ⎜
# 炫
# 🐢
# 浴
# ੌ
# 舖
# 
# 笼
# 声
# 比
# 석
# 
# ር
# ສ
# ಥ
# 🏠
# મ
# 
# 教
# ピ
# 榨
# ✧
# 패
# る
# 愈
# 
# 形
# ।
# 卷
# 
# ⚑
# ท
# 🧐
# 铃
# 
# ึ
# 暨
# 損
# َ
# ி
# 到
# 冈
# 興
# 想
# 마
# ᴍ
# 晚
# ೇ
# 染
# 圭
# 扣
# 
# 敦
# 估
# ฬ
# 🚢
# い
# י
# 樣
# 答
# å
# 牛
# 報
# 构
# ⬅
# ঠ
# 夏
# 💧
# ゆ
# 易
# 
# ἠ
# 멍
# 蜜
# 교
# ィ
# 🍺
# 𝗽
# ◉
# 谱
# 私
# 寫
# 足
# ⁠
# 具
# Ú
# 彭
# ر
# 塘
# 
# 
# 🧟
# ย
# 렇
# 아
# 
# 帕
# х
# 
# 稀
# 辩
# 方
# 针
# 取
# ɬ
# ਨ
# 
# 读
# 绰
# 🍔
# 鞔
# 终
# ꜰ
# 颈
# 冰
# 🎄
# 
# 郵
# 舎
# 林
# 卜
# 危
# 廣
# 要
# 완
# 猫
# 夕
# 襟
# 雑
# 筍
# 班
# 殊
# 湖
# 🚩
# ▪
# 였
# ∧
# 
# 
#
# 袁
# 🤫
# 冲
# ◆
# ጉ
# 已
# 5
# 顕
# 를
# 庆
# 鲍
# 署
# ﾉ
# 
# 辑
# 😀
# ➟
# ṣ
# 
# 👏
# ♿
# 持
# ధ
# 変
# ऑ
# 一
#
# ெ
# 
# Γ
# 莞
# 獣
# ✌
# υ
# 泻
# Қ
# ತ
# 
# 廊
# 缠
# 赌
# 蚁
# ở
# 𝐑
# 𝗩
# 載
# 踏
# 快
# 导
# ً
# 
# 井
# 류
# 涕
# 
# 幅
# ฝ
# 勒
# 盛
# 🍣
# ㄨ
# ♤
# ያ
# г
# 参
# 倩
# 习
# 傲
# 白
# 电
# ూ
# 願
# ／
# キ
# 
# 俩
# 𝟒
# 
# 小
# 
# 据
# 𝟏
# 􀈣
# 制
# 
# 资
# 千
# 脆
# 
# 
# 
# ம
# 恕
# 
# 續
# 培
# 啡
# 副
# 污
# ⬩
# 稼
# 
# 屡
# ผ
# ボ
# 
# ế
# 
# 连
# 관
# 梱
# 倒
# 拟
# 盐
# 
# 되
# 窒
# ક
# 時
# 
# 轿
# ο
# 
# Ž
# 荷
# 
# 🤵
# 責
# 
# ऐ
# 叙
# 慧
# 意
# 
# 종
# ✼
# 貨
# 🍦
# 
# च
# 妹
# 淤
# 痴
# ῇ
# 怨
# 帯
# 商
# ←
# 慷
# 枣
# 证
# 
# 
# ✙
# 欥
# 恆
# 靠
# 楠
# □
# 寂
# რ
# 玲
# 档
# ș
# ﻯ
# 叛
# ⟩
# फ
# 󰁒
# 👯
# ⇗
# 
# ฉ
# 量
# 闵
# χ
# ़
# ☺
# 
# ≅
# 心
# 🇦
# য
#
# 颠
# 俱
# ❘
# 圈
# 👌
# 使
# 怡
# 
# 
# ૈ
# 🦕
# 
# 树
# 粘
# ރ
# ⅞
# પ
# 渴
# 阁
# 🤣
# आ
# 套
# æ
# ল
# 着
# ｶ
# િ
# 遥
# Ẩ
# 호
# 抑
# ❄
# 😲
# 循
# 压
# 뉴
# 卿
# ů
# 者
# 栏
# 焦
# 涵
# 食
# ഷ
# 滩
# 수
# 们
# ዘ
# ạ
# 🎊
# 
# 费
# 室
# 荨
# 实
# ḵ
# 電
# 날
# ೖ
# 披
# ⁺
# 兽
# Υ
# 👱
# 栎
# ή
# 운
# 贱
# נ
# 鹰
# §
# 掛
# 😡
# 接
# 潜
# ル
# 裂
# 🐻
# ♂
# 何
# 稳
# 潮
# 馈
# 💹
# ዳ
# 기
# ஷ
# 🡥
# 寧
# ἡ
# খ
# 
# ユ
# ∑
# 赞
# 邹
# 根
# ⌊
# 穆
# 袂
# 疆
# 🔌
# 炭
# 間
# 畸
# 料
#
# 
# 応
# 받
# 几
# 韧
# 訊
# φ
# 斎
# 藓
# 
# 扫
# ﻿
# ₱
# 骑
# 統
# 乗
# ణ
# س
# 逢
# 祸
# 戴
# ○
# 
# ʊ
# ಛ
# 像
# 堂
# 庁
# 😕
# 😁
# 挡
# ἀ
# 
# 綫
# 毒
# 股
# ﻮ
# औ
# 
# 안
# 天
# 津
# ∼
# ա
# 朋
# ằ
# ʷ
# ї
# 南
# 联
# 🇭
# 賃
# ト
# ‪
# 翰
# ص
# 자
# 贪
#
# 
# 🛁
# 弟
# ក
# 
# 
# 桥
# 伏
# 獨
# ⇐
# Ｚ
# ഇ
# 언
# 渓
# 局
# ျ
# ൊ
# 납
# 鲤
# Ţ
# ᐳ
# 淹
# 稅
# 厦
# ◇
# Ⓡ
# 评
# ್
# 失
# 启
# ొ
# 
# ﻓ
# 😓
# 異
# 캐
# 开
# ợ
# 洗
# 詞
# ｼ
# 享
# 🦇
# 板
# 溢
# 奮
# 需
# க
# 氧
# 章
# 清
# 터
# 拱
# 

# %% [markdown]
# # Text Cleaning

# %%
import string
import unicodedata as ud
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

from nltk.stem.snowball import SnowballStemmer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# this function removes emojis and also converts visually similar characters to normat Lating characters
def to_unicode(text):
    return ud.normalize('NFD', text).encode('ascii','ignore').decode('utf-8')

# function to remove punctuations
def remove_punctuation(text):
    lst = [c for c in text if c not in string.punctuation]
    return ''.join(lst)


stop_words = stopwords.words('english')
stop_words.extend(['contact','us'])

# function to remove stopwords
def remove_stopwords(text):
    lst = [word for word in text.split() if word not in stop_words]
    return ' '.join(lst)


stemmer = SnowballStemmer('english')

# function for stemming
def stemming(text):
    l = [stemmer.stem(word) for word in text.split()]
    return " ".join(l)

# %%
# function for cleaning text
def clean_text(text):
    text = to_unicode(text)
    text = remove_punctuation(text)
    text = remove_stopwords(text)
    text = stemming(text)

    return text

# %%
# cleaning the text column
df2['text'] = df2['text'].apply(clean_text)
# Out:
# <ipython-input-35-50dc23e78015>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['text'] = df2['text'].apply(clean_text)

# %%
df2
# Out:
#                       website               company_name  \
# 0             bipelectric.com  bip dipietro electric inc
# 1            eliasmedical.com              elias medical
# 2      koopsoverheaddoors.com       koops overhead doors
# 3             midtowneyes.com            midtown eyecare
# 4         reprosecurity.co.uk         repro security ltd
# ...                       ...                        ...
# 70645          nayyarsons.com            nayyarsons food
# 70646  claddaghcoffeecafe.com            claddagh coffee
# 70647    beautyologist.com.au              beautyologist
# 70648        beautycall.co.uk                beauty call
# 70649     littleladyfoods.com          little lady foods
#
#                                                     text
# 0      electrician electr contractor serv vero beach ...
# 1      site map en espanol elia medic home skin care ...
# 2      home about us garag door repair servic designa...
# 3      9185990202 type size a a a home our practic ou...
# 4      simpli fill form back touch arrang free no obl...
# ...                                                  ...
# 70645  nayyarson deli bakeri food servic nayyarson co...
# 70646  home about us our shop west seventh wee shop s...
# 70647  03 9531 5092 make a book beautyologist beauti ...
# 70648  enquir get touch 0800 170 7370 galleri price r...
# 70649  what our partner whi choos our famili contact ...
#
# [70650 rows x 3 columns]

# %%
# we also need to remove numbers from the text
def remove_number(text):
    return ''.join([i for i in text if not i.isdigit()])

# %%
df2['text'] = df2['text'].apply(remove_number)
# Out:
# <ipython-input-38-661f35bf2cba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['text'] = df2['text'].apply(remove_number)

# %%
df2.columns
# Out:
# Index(['website', 'company_name', 'text'], dtype='object')

# %%
df2.head()
# Out:
#                   website               company_name  \
# 0         bipelectric.com  bip dipietro electric inc
# 1        eliasmedical.com              elias medical
# 2  koopsoverheaddoors.com       koops overhead doors
# 3         midtowneyes.com            midtown eyecare
# 4     reprosecurity.co.uk         repro security ltd
#
#                                                 text
# 0  electrician electr contractor serv vero beach ...
# 1  site map en espanol elia medic home skin care ...
# 2  home about us garag door repair servic designa...
# 3   type size a a a home our practic our servic p...
# 4  simpli fill form back touch arrang free no obl...

# %%
df2['text'].shape
# Out:
# (70650,)



# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# creating vectorizer object
vectorizer = TfidfVectorizer(max_df=0.8, min_df=0.02)

# %%
X = vectorizer.fit_transform(data['text'])

# %%
data['text']
# Out:
# 0        electrician electr contractor serv vero beach ...
# 1        site map en espanol elia medic home skin care ...
# 2        home about us garag door repair servic designa...
# 3         type size a a a home our practic our servic p...
# 4        simpli fill form back touch arrang free no obl...
#                                ...
# 70645    nayyarson deli bakeri food servic nayyarson co...
# 70646    home about us our shop west seventh wee shop s...
# 70647       make a book beautyologist beauti salon shop...
# 70648    enquir get touch    galleri price review artis...
# 70649    what our partner whi choos our famili contact ...
# Name: text, Length: 70650, dtype: object

# %%
X.shape
# Out:
# (70650, 1806)

# %% [markdown]
# # Making Clusters

# %% [markdown]
# Clustering such huge data on GPU will take a lot of time. So we have to create clusters on GPU.

# %%
# %%capture
# !pip install kmeanstf

# %%
from kmeanstf import KMeansTF
from scipy.spatial.distance import cdist

# %%
type(X)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
X = X.toarray()

# %%
# Within Cluster sum of Squares score
# for determining the right number of clusters
distortions = []

# %%
K = range(2,21)
for k in K:
    model = KMeansTF(n_clusters=k, random_state=42)
    model.fit(X)
    distortions.append(sum(np.min(cdist(X, model.cluster_centers_, 'euclidean'), axis=1)) / X.shape[0])
# Out:
# matrix too large for GPU: bytes 6,124,507,200, k=12 n=70,650 d=1806 numsize=4, max_mem=11,888,492,544
# automated slicing started
# set 'verbose' to 1 to see more details
# fraction matrix too large for GPU: bytes 3,062,253,600, k=12 n=35,325 d=1806 numsize=4, max_mem=6,124,507,199
# matrix too large for GPU: bytes 6,634,882,800, k=13 n=70,650 d=1806 numsize=4, max_mem=11,888,492,544
# automated slicing started
# set 'verbose' to 1 to see more details
# fraction matrix too large for GPU: bytes 3,317,441,400, k=13 n=35,325 d=1806 numsize=4, max_mem=6,634,882,799
# matrix too large for GPU: bytes 7,145,258,400, k=14 n=70,650 d=1806 numsize=4, max_mem=11,888,492,544
# automated slicing started
# set 'verbose' to 1 to see more details
# fraction matrix too large for GPU: bytes 3,572,629,200, k=14 n=35,325 d=1806 numsize=4, max_mem=7,145,258,399
# matrix too large for GPU: bytes 7,655,634,000, k=15 n=70,650 d=1806 numsize=4, max_mem=11,888,492,544
# automated slicing started
# set 'verbose' to 1 to see more details
# fraction matrix too large for GPU: bytes 3,827,817,000, k=15 n=35,325 d=1806 numsize=4, max_mem=7,655,633,999
# fraction matrix too large for GPU: bytes 2,551,878,000, k=15 n=23,550 d=1806 numsize=4, max_mem=3,445,035,300
# matrix too large for GPU: bytes 8,166,009,600, k=16 n=70,650 d=1806 numsize=4, max_mem=11,888,492,544
# automated slicing started
# set 'verbose' to 1 to see more details
# fraction matrix too large for GPU: bytes 4,083,004,800, k=16 n=35,325 d=1806 numsize=4, max_mem=8,166,009,599
# fraction matrix too large for GPU: bytes 2,722,003,200, k=16 n=23,550 d=1806 numsize=4, max_mem=3,674,704,320
# matrix too large for GPU: bytes 8,676,385,200, k=17 n=70,650 d=1806 numsize=4, max_mem=11,888,492,544
# automated slicing started
# set 'verbose' to 1 to see more details
# fraction matrix too large for GPU: bytes 4,338,192,600, k=17 n=35,325 d=1806 numsize=4, max_mem=8,676,385,199
# fraction matrix too large for GPU: bytes 2,892,128,400, k=17 n=23,550 d=1806 numsize=4, max_mem=3,904,373,340
# fraction matrix too large for GPU: bytes 2,169,034,896, k=17 n=17,662 d=1806 numsize=4, max_mem=2,602,915,560
# matrix too large for GPU: bytes 9,186,760,800, k=18 n=70,650 d=1806 numsize=4, max_mem=11,888,492,544
# automated slicing started
# set 'verbose' to 1 to see more details
# fraction matrix too large for GPU: bytes 4,593,380,400, k=18 n=35,325 d=1806 numsize=4, max_mem=9,186,760,799
# fraction matrix too large for GPU: bytes 3,062,253,600, k=18 n=23,550 d=1806 numsize=4, max_mem=4,134,042,360
# fraction matrix too large for GPU: bytes 2,296,625,184, k=18 n=17,662 d=1806 numsize=4, max_mem=2,756,028,240
# fraction matrix too large for GPU: bytes 1,837,352,160, k=18 n=14,130 d=1806 numsize=4, max_mem=2,066,962,665
# matrix too large for GPU: bytes 9,697,136,400, k=19 n=70,650 d=1806 numsize=4, max_mem=11,888,492,544
# automated slicing started
# set 'verbose' to 1 to see more details
# fraction matrix too large for GPU: bytes 4,848,568,200, k=19 n=35,325 d=1806 numsize=4, max_mem=9,697,136,399
# fraction matrix too large for GPU: bytes 3,232,378,800, k=19 n=23,550 d=1806 numsize=4, max_mem=4,363,711,380
# fraction matrix too large for GPU: bytes 2,424,215,472, k=19 n=17,662 d=1806 numsize=4, max_mem=2,909,140,920
# fraction matrix too large for GPU: bytes 1,939,427,280, k=19 n=14,130 d=1806 numsize=4, max_mem=2,181,793,924
# fraction matrix too large for GPU: bytes 1,616,189,400, k=19 n=11,775 d=1806 numsize=4, max_mem=1,745,484,552
# fraction matrix too large for GPU: bytes 1,385,187,552, k=19 n=10,092 d=1806 numsize=4, max_mem=1,454,570,460
# matrix too large for GPU: bytes 10,207,512,000, k=20 n=70,650 d=1806 numsize=4, max_mem=11,888,492,544
# automated slicing started
# set 'verbose' to 1 to see more details
# fraction matrix too large for GPU: bytes 5,103,756,000, k=20 n=35,325 d=1806 numsize=4, max_mem=10,207,511,999
# fraction matrix too large for GPU: bytes 3,402,504,000, k=20 n=23,550 d=1806 numsize=4, max_mem=4,593,380,400
# fraction matrix too large for GPU: bytes 2,551,805,760, k=20 n=17,662 d=1806 numsize=4, max_mem=3,062,253,600
# fraction matrix too large for GPU: bytes 2,041,502,400, k=20 n=14,130 d=1806 numsize=4, max_mem=2,296,625,184
# fraction matrix too large for GPU: bytes 1,701,252,000, k=20 n=11,775 d=1806 numsize=4, max_mem=1,837,352,160
# fraction matrix too large for GPU: bytes 1,458,092,160, k=20 n=10,092 d=1806 numsize=4, max_mem=1,531,126,800
# fraction matrix too large for GPU: bytes 1,275,902,880, k=20 n=8,831 d=1806 numsize=4, max_mem=1,312,282,944
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-55-6378730b4239> in <cell line: 2>()
#       2 for k in K:
#       3     model = KMeansTF(n_clusters=k, random_state=42)
# ----> 4     model.fit(X)
#       5     distortions.append(sum(np.min(cdist(X, model.cluster_centers_, 'euclidean'), axis=1)) / X.shape[0])
#
# /usr/local/lib/python3.10/dist-packages/kmeanstf/kmeanstf.py in fit(self, X)
#     505             self._log["init_duration"], self._log["lloyd_duration"], \
#     506             self._log["kmeans_lloyd_iter"],     = \
# --> 507             self._k_means(
#     508                 X,
#     509                 n_clusters=self.n_clusters,
#
# /usr/local/lib/python3.10/dist-packages/kmeanstf/kmeanstf.py in _k_means(self, X, n_clusters, init, n_init, max_iter, tol, direct_call_from_fit)
#     648                 # create copy to measure tol
#     649                 centroids_old = current_centroids+0
# --> 650                 sse, nearest_indices = self._get_sse_and_nearest_centroids(X, current_centroids, direct_call_from_fit)
#     651                 #
#     652                 # sometimes nan's occur, replace with centroids_old
#
# /usr/local/lib/python3.10/dist-packages/kmeanstf/kmeanstf.py in _get_sse_and_nearest_centroids(self, X, centroids, direct_call_from_fit)
#    1262                     # compute partial SSE
#    1263                     sse_f = tf.reduce_sum(
# -> 1264                         tf.reduce_min(distances_f, 0)).numpy()
#    1265                     sse += sse_f
#    1266                     # compute partial list of nearest_centroids
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1158     """
#    1159     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1160     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1161     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1162
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1126       return self._numpy_internal()
#    1127     except core._NotOkStatusException as e:  # pylint: disable=protected-access
# -> 1128       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#    1129
#    1130   @property
#
# InternalError: Could not synchronize CUDA stream: CUDA_ERROR_ILLEGAL_ADDRESS: an illegal memory access was encountered

# %%
distortions

# %%
len(distortions)

# %%
# Plot the elbow
plt.figure(figsize=(20,10))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %% [markdown]
# If we look carefully, we can observe that between k=12 to 13, there is a relatively significant drop in the score but after k=13, there is no significant dip in the graph. So we can go with 13 clusters.

# %% [markdown]
# Now let's try sihoutte score

# %%
from sklearn.metrics import silhouette_score

# %% [markdown]
# Calculating sihoutte_score is a complex process and will take forever on a dataset this huge. But! We have a solution. Instead of using whole cluster, we can use a sample of each cluster to calculate Silhoutte scores and can decide on number of clusters.

# %%
def sample_silhoutte_score(X, y, ratio=0.1):
    # getting number of clusters
    k = max(y)+1

    # create a dictionary where keys are cluster label
    # and values are list of indices of the points alotted to the label
    cluster_dict = {i:np.where(y==i)[0] for i in range(k)}

    # creating samples
    y_sample = []
    X_sample = []

    for i in cluster_dict.keys():
        sample_size = int(cluster_dict[i].shape[0]*ratio)
        indexes = np.random.choice(a=cluster_dict[i], size=sample_size)
        sample = np.take(a=X, indices=indexes, axis=0)
        labels = [i]*sample_size
        y_sample.extend(labels)
        X_sample.extend(sample)

    return silhouette_score(np.array(X_sample), y_sample)

# %%
scores = []

for k in range(2,21):
    model = KMeansTF(n_clusters=k, random_state=42)
    y = model.fit_predict(X)
    # taking 30% ratio
    score = sample_silhoutte_score(X, y, ratio=0.3)
    scores.append(score)

# %%
plt.plot(range(2,21), scores, 'bx-')
plt.xlabel('k')
plt.ylabel('Silhoutte Score')
plt.title('Slhoutte Score VS number of clusters')
plt.show()

# %% [markdown]
# ## Let's Make four Clusters

# %%
kmeanstf = KMeansTF(n_clusters=13)

# %%
y = kmeanstf.fit_predict(X)

# %%
np.unique(y, return_counts=True)

# %%
# let's collect text for all four clusters
data['label'] = y

text = []

for i in range(13):
    cluster_df = data[data['label']==i]
    text.append(' '.join(list(cluster_df['text'])))

# %%
text

# %%
len(text)

# %%
print(text)

# %%
from wordcloud import WordCloud

# %%
np.unique(y, return_counts=True)

# %%
# fucntion to create wordcloud
def word_cloud(text):
    wordcloud = WordCloud().generate(text)
    plt.figure(figsize=(10,10))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %% [markdown]
# Legal Affairs

# %%
word_cloud(text[0])

# %% [markdown]
# Industry manufacturing

# %%
word_cloud(text[1])

# %% [markdown]
# financial

# %%
word_cloud(text[2])

# %% [markdown]
# Financial

# %%
word_cloud(text[3])

# %% [markdown]
# Financial

# %%
word_cloud(text[4])

# %% [markdown]
# Health care

# %%
word_cloud(text[5])

# %% [markdown]
# Insurance

# %%
word_cloud(text[6])

# %% [markdown]
# IT

# %%
word_cloud(text[7])

# %% [markdown]
# hospitatility

# %%
word_cloud(text[8])

# %% [markdown]
# Real Estate

# %%
word_cloud(text[9])

# %% [markdown]
# digital marketing

# %%
word_cloud(text[10])

# %% [markdown]
# energy

# %%
word_cloud(text[11])

# %% [markdown]
# logistics

# %%
word_cloud(text[12])
